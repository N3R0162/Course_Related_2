# %%
import cv2
import matplotlib.pyplot as plt

# load the meanface from file
with open('meanface.txt', 'r') as f:
    meanface = f.readline().strip().split()
meanface = [float(x) for x in meanface]

# load some sample images from the dataset
img1 = cv2.imread('data/train/0001.jpg')
img2 = cv2.imread('data/train/0002.jpg')
img3 = cv2.imread('data/train/0003.jpg')

# plot the meanface and sample images side by side
fig, axs = plt.subplots(1, 4, figsize=(10, 5))
axs[0].imshow(np.array(meanface).reshape(-1, 2))
axs[0].set_title('Meanface')
axs[1].imshow(cv2.cvtColor(img1, cv2.COLOR_BGR2RGB))
axs[1].set_title('Image 1')
axs[2].imshow(cv2.cvtColor(img2, cv2.COLOR_BGR2RGB))
axs[2].set_title('Image 2')
axs[3].imshow(cv2.cvtColor(img3, cv2.COLOR_BGR2RGB))
axs[3].set_title('Image 3')
plt.show()
# Out:
# 119.000000 185.000000
#
# 118.000000 196.000000
#
# 116.000000 206.000000
#
# 115.000000 217.000000
#
# 115.000000 228.000000
#
# 115.000000 239.000000
#
# 117.000000 250.000000
#
# 119.000000 261.000000
#
# 122.000000 272.000000
#
# 126.000000 283.000000
#
# 131.000000 293.000000
#
# 136.000000 302.000000
#
# 142.000000 311.000000
#
# 148.000000 321.000000
#
# 155.000000 330.000000
#
# 164.000000 338.000000
#
# 175.000000 343.000000
#
# 190.000000 344.000000
#
# 205.000000 342.000000
#
# 219.000000 338.000000
#
# 232.000000 332.000000
#
# 244.000000 325.000000
#
# 256.000000 318.000000
#
# 266.000000 309.000000
#
# 275.000000 299.000000
#
# 283.000000 288.000000
#
# 289.000000 275.000000
#
# 293.000000 263.000000
#
# 296.000000 250.000000
#
# 298.000000 237.000000
#
# 299.000000 223.000000
#
# 300.000000 210.000000
#
# 300.000000 197.000000
#
# 125.000000 167.000000
#
# 132.000000 161.000000
#
# 141.000000 160.000000
#
# 150.000000 163.000000
#
# 158.000000 168.000000
#
# ...

# %%
x = 2147483648
y = 18446744073692774399
